# %% [markdown]
# # Opensearch query example
#
# This notebook serves as a fully working Opensearch query example that we can use for discussion and development before adding the constraints of request and response models and tests.
#
# There are various TODOs in here indicating some of the decisions that need to be made.

# %%
# %load_ext autoreload
# %autoreload 2

import time

import numpy as np

from app.index import OpenSearchIndex
from app.ml import SBERTEncoder
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1a. Connect to Opensearch
# As we're outside of docker-compose we'll connect to Opensearch via localhost.

# %%
opensearch = OpenSearchIndex(
    url="http://localhost:9200",
    username="admin",
    password="admin",
    index_name="navigator",
    # TODO: convert to env variables?
    opensearch_connector_kwargs={
        "use_ssl": False,
        "verify_certs": False,
        "ssl_show_warn": False,
    },
    embedding_dim=768,
)

print(opensearch.is_connected())

opns = opensearch.opns
# Out:
# True

# %% [markdown]
# ### 1b. Load sentence-BERT encoder
#
# This is used to generate embeddings for semantic search.

# %%
# TODO: this needs to be the same model as used for indexing. At a later stage when we start updating 
# models we may want a way of ensuring both models are the same.
enc = SBERTEncoder(model_name="msmarco-distilbert-dot-v5")
enc.encode("hello world").shape
# Out:
# (768,)

# %%
emba = enc.encode("bicycle race")
embb = enc.encode("car race")
embc = enc.encode("tortoise race")

np.dot(emba, embb), np.dot(emba, embc)
# Out:
# (80.994026, 76.67018)

# %% [markdown]
# ### 2. Run search
#
# The `run_query` function does all of the heavy lifting here. See various TODOs and [issue #420](https://github.com/climatepolicyradar/navigator/issues/420) for discussion points.

# %%
def _innerproduct_threshold_to_lucene_threshold(ip_thresh: float) -> float:
    """
    Opensearch documentation on mapping similarity functions to Lucene thresholds is here: https://github.com/opensearch-project/k-NN/blob/main/src/main/java/org/opensearch/knn/index/SpaceType.java#L33
    It defines 'inner product' as negative inner product i.e. a distance rather than similarity measure, so we reverse the signs of inner product here compared to the docs.
    """
    if ip_thresh > 0:
        return ip_thresh + 1
    else:
        return 1 / (1-ip_thresh)
    

def run_query(query: str, innerproduct_threshold: float, max_passages_per_doc: int) -> dict:
    embedding = enc.encode(query)
    lucene_threshold = _innerproduct_threshold_to_lucene_threshold(innerproduct_threshold)

    opns_query = {
                "size": 0, # only return aggregations
                "query": {
                    "bool": {
                        "should": [
                            # Text passage matching
                            {
                                "match": {
                                    "text": {
                                        "query": query,
                                        "boost": 1,
                                    },
                                }
                            },
                            {
                                "match_phrase": {
                                    "text": {
                                        "query": query,
                                        "boost": 1,
                                    },
                                }
                            },
                            # Text passage semantic search (KNN)
                            {
                                # TODO: setting the KNN threshold to high essentially filters out the KNN results but leaves the others in.
                                # This should be documented.
                                "function_score": {
                                    "query": {
                                        "knn": {
                                            "text_embedding": {
                                                "vector": embedding,
                                                # TODO: this k value should match above
                                                "k": 10,
                                            },
                                        },
                                    },
                                    "min_score": lucene_threshold
                                }
                            },
                            # Action (to be document) title matching
                            {
                                "match_phrase": {
                                    "name": {
                                        "query": query,
                                        "boost": 10,
                                    },
                                }
                            },
                            # {
                            #     "prefix": {
                            #         "name": {
                            #             "value": query,
                            #             "boost": 10,
                            #             "case_insensitive": True,
                            #         },
                            #     }
                            # },
                            # Action (to be document) description matching
                            {
                                "match": {
                                    "description": {
                                        "query": query,
                                        "boost": 1,
                                    },
                                }
                            },
                        ],
                        "minimum_should_match": 1,
                    },
                },
                "aggs": {
                    "top_docs": {
                        "terms": {
                            "field": "document_id",
                            "order": {"top_hit": "desc"},
                        },
                        "aggs": {
                            "top_passage_hits": {
                                "top_hits": {
                                    "_source": {"excludes": ["text_embedding"]},
                                    "size": max_passages_per_doc,
                                }
                            },
                            "top_hit": {"max": {"script": {"source": "_score"}}},
                        },
                    }
                },
            }
    
    start = time.time()
    response = opns.search(
        body=opns_query,
        index="navigator",
        request_timeout=30,
        preference="prototype_user", # TODO: document what this means
        explain=True,
    )
    end = time.time()
    print(f"query execution time: {round(end-start, 2)}s")
    
    return response

# TODO: we should experimentally adjust this threshold 
run_query(
    "National Home Retrofit Scheme 2020 (One Stop Shop Development Call)", 
    innerproduct_threshold=70, # Same as prototype
    max_passages_per_doc=10
)
# Out:
# query execution time: 0.27s
# {'took': 255,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 2835, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'top_docs': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 944,
#    'buckets': [{'key': '1151',
#      'doc_count': 116,
#      'top_hit': {'value': 192.987548828125},
#      'top_passage_hits': {'hits': {'total': {'value': 116, 'relation': 'eq'},
#        'max_score': 192.98755,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '57RI1X8B6OZKDs8-mUPu',
#          '_score': 192.98755,
#          '_source': {'document_name': "Scheme's guidelines",
#           'country_code': 'IRL',
#           'action_id': 913,
#           'action_source_name': 'CCLW',
#           'name': 'National Home Retrofit Scheme 2020 (One Stop Shop Development Call)',
#           'action_date': '25/12/2020',
#           'document_id': 1151,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '7rRI1X8B6OZKDs8-mUPu',
#          '_score': 178.99602,
#          '_source': {'document_name': "Scheme's guidelines",
#           'country_code': 'IRL',
#           'action_id': 913,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p2_b6',
#           'action_date': '25/12/2020',
#           'text': 'The Sustainable Energy Authority of Ireland (SEAI) is delighted to announce the launch of the National \nHome Retrofit Scheme 2020 (One Stop Shop Development Call).',
#           'document_id': 1151,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '6rRI1X8B6OZKDs8-mUPu',
#          '_score': 123.86422,
#          '_source': {'document_name': "Scheme's guidelines",
#           'country_code': 'IRL',
#           'action_id': 913,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p0_b2',
#           'action_date': '25/12/2020',
#           'text': '(One Stop Shop Development Call)',
#           'document_id': 1151,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '6bRI1X8B6OZKDs8-mUPu',
#          '_score': 121.60079,
#          '_source': {'document_name': "Scheme's guidelines",
#           'country_code': 'IRL',
#           'action_id': 913,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p0_b1',
#           'action_date': '25/12/2020',
#           'text': 'National Home Retrofit Scheme 2020',
#           'document_id': 1151,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '-rRI1X8B6OZKDs8-mUPu',
#          '_score': 121.60079,
#          '_source': {'document_name': "Scheme's guidelines",
#           'country_code': 'IRL',
#           'action_id': 913,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p3_b18',
#           'action_date': '25/12/2020',
#           'text': 'National Home Retrofit Scheme 2020',
#           'document_id': 1151,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'VLRI1X8B6OZKDs8-mUXu',
#          '_score': 108.052376,
#          '_source': {'document_name': "Scheme's guidelines",
#           'country_code': 'IRL',
#           'action_id': 913,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p14_b364',
#           'action_date': '25/12/2020',
#           'text': 'The National Home Retrofit Scheme 2020 aims at \nsupporting retrofits for old building stock. Homes constructed after 1 January 2006 are not \neligible for standard measures or after 1 January 2011 for heat pump installs. The National \nHome Retrofit Scheme does not support works carried out during construction.',
#           'document_id': 1151,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '3bRI1X8B6OZKDs8-mUTu',
#          '_score': 107.266205,
#          '_source': {'document_name': "Scheme's guidelines",
#           'country_code': 'IRL',
#           'action_id': 913,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p12_b245',
#           'action_date': '25/12/2020',
#           'text': 'The following energy efficiency upgrades are eligible for funding as part of the National Home Retrofit \nScheme 2020',
#           'document_id': 1151,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'DLRI1X8B6OZKDs8-nUeh',
#          '_score': 107.190346,
#          '_source': {'document_name': "Scheme's guidelines",
#           'country_code': 'IRL',
#           'action_id': 913,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p30_b804',
#           'action_date': '25/12/2020',
#           'text': '6 THE NATIONAL HOME RETROFIT SCHEME GRANT TEAM',
#           'document_id': 1151,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'IrRI1X8B6OZKDs8-mUTu',
#          '_score': 105.09673,
#          '_source': {'document_name': "Scheme's guidelines",
#           'country_code': 'IRL',
#           'action_id': 913,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p4_b58',
#           'action_date': '25/12/2020',
#           'text': 'The National Home Retrofit Scheme aims to fund a comprehensive suite of projects that deliver \nenergy savings to homes. An eligible application must target one of the following:',
#           'document_id': 1151,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'ObRI1X8B6OZKDs8-mUTu',
#          '_score': 105.04554,
#          '_source': {'document_name': "Scheme's guidelines",
#           'country_code': 'IRL',
#           'action_id': 913,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p5_b81',
#           'action_date': '25/12/2020',
#           'text': 'The One-Stop-Shop approach is encouraged in all applications. The Midlands strand of the scheme is \nopen to applicants who have all or part of the elements of One-Stop-Shops and can demonstrate \npartnership and collaboration with the Local Authorities to deliver efficiencies by aggregating retrofit \nworks.',
#           'document_id': 1151,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}}]}}},
#     {'key': '2063',
#      'doc_count': 77,
#      'top_hit': {'value': 84.93712615966797},
#      'top_passage_hits': {'hits': {'total': {'value': 77, 'relation': 'eq'},
#        'max_score': 84.937126,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'srRI1X8B6OZKDs8-wmMS',
#          '_score': 84.937126,
#          '_source': {'document_name': 'Full text English',
#           'country_code': 'ROU',
#           'action_id': 1640,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p24_b694',
#           'action_date': '10/01/2017',
#           'text': 'expanding the National programme for energy efficiency (retrofitting the heating system, retrofitting \npublic buildings) for the period 2016-2020;',
#           'document_id': 2063,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '-LRI1X8B6OZKDs8-v2Kl',
#          '_score': 82.26567,
#          '_source': {'document_name': 'Full text English',
#           'country_code': 'ROU',
#           'action_id': 1640,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p18_b508',
#           'action_date': '10/01/2017',
#           'text': ': new buildings constructed between now and 2020 will probably be subject to \nrenovation in the period up to 2050, even if only to replace heating, ventilation or air-conditioning \n(HVAC) equipment. Furthermore, as energy standards for renovation are tightened and new \ntechnologies become more widely available and affordable, these will increasingly be deployed on \nbuildings constructed this decade. The rate of new build is set at 0.85% based on the average useful \nfloor area of dwellings finished in the period 1990-2012. Beyond 2020, it is assumed that nZEB \nrequirements under the recast of the EPBD will result in buildings achieving a level of energy \nperformance that will not require further renovation (other than equipment replacement) until 2050.',
#           'document_id': 2063,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'J7RI1X8B6OZKDs8-wmQS',
#          '_score': 77.69266,
#          '_source': {'document_name': 'Full text English',
#           'country_code': 'ROU',
#           'action_id': 1640,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p32_b811',
#           'action_date': '10/01/2017',
#           'text': "Encouraging the initiatives of private banks (e.g. 'Green Mortgages/Green Loans') with attractive \nterms for owners who wish to renovate their buildings at high energy efficiency and sustainability \nstandards (deep renovation); in June 2017, EBRD's Green Economy Financing Facility (GEFF) \nproject was launched, with a value of EUR 100 million.",
#           'document_id': 2063,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '5bRI1X8B6OZKDs8-wmMS',
#          '_score': 9.481595,
#          '_source': {'document_name': 'Full text English',
#           'country_code': 'ROU',
#           'action_id': 1640,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p25_b745',
#           'action_date': '10/01/2017',
#           'text': 'Introducing an obligation scheme for 2016-2020 may be considered only in the event that the impact on \nenergy prices',
#           'document_id': 2063,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'pbRI1X8B6OZKDs8-wmMS',
#          '_score': 6.9044566,
#          '_source': {'document_name': 'Full text English',
#           'country_code': 'ROU',
#           'action_id': 1640,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p24_b681',
#           'action_date': '10/01/2017',
#           'text': '2020',
#           'document_id': 2063,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'ErRI1X8B6OZKDs8-vWEZ',
#          '_score': 6.885156,
#          '_source': {'document_name': 'Full text English',
#           'country_code': 'ROU',
#           'action_id': 1640,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p2_b22',
#           'action_date': '10/01/2017',
#           'text': '(Source: (National Research and Development Institute for Construction, Urban Planning and Sustainable \nTerritorial Development',
#           'document_id': 2063,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'obRI1X8B6OZKDs8-wmMS',
#          '_score': 6.8175793,
#          '_source': {'document_name': 'Full text English',
#           'country_code': 'ROU',
#           'action_id': 1640,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p24_b677',
#           'action_date': '10/01/2017',
#           'text': 'The national strategy on the sustainable development of Romania',
#           'document_id': 2063,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'NLRI1X8B6OZKDs8-v2Kl',
#          '_score': 6.056819,
#          '_source': {'document_name': 'Full text English',
#           'country_code': 'ROU',
#           'action_id': 1640,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p10_b312',
#           'action_date': '10/01/2017',
#           'text': "', coordinated by the National \nResearch and Development Institute for Construction, Urban Planning and Sustainable Territorial \nDevelopment 'Urban-Incerc' (INCD URBAN-INCERC) (",
#           'document_id': 2063,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'frRI1X8B6OZKDs8-wmQS',
#          '_score': 5.8852673,
#          '_source': {'document_name': 'Full text English',
#           'country_code': 'ROU',
#           'action_id': 1640,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p35_b898',
#           'action_date': '10/01/2017',
#           'text': '13% in 2020 and to 8',
#           'document_id': 2063,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'w7RI1X8B6OZKDs8-v2Gl',
#          '_score': 5.7613134,
#          '_source': {'document_name': 'Full text English',
#           'country_code': 'ROU',
#           'action_id': 1640,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p8_b199',
#           'action_date': '10/01/2017',
#           'text': 'to \nprovide itself with sufficient levels of thermal comfort in the home, because of the high cost of',
#           'document_id': 2063,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}}]}}},
#     {'key': '2530',
#      'doc_count': 367,
#      'top_hit': {'value': 82.9735336303711},
#      'top_passage_hits': {'hits': {'total': {'value': 367, 'relation': 'eq'},
#        'max_score': 82.97353,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '2LRI1X8B6OZKDs8-8oqh',
#          '_score': 82.97353,
#          '_source': {'document_name': 'full text (PDF)',
#           'country_code': 'TTO',
#           'action_id': 2018,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p16_b123',
#           'action_date': '25/12/2016',
#           'text': 'The NDS builds on the vast consultation process of Vision 2020, which involved over 80 national consultations and 27 sub-committees comprising academia, the public and private sectors and civil society. In so doing, the Vision 2020 National Vision was primarily retained given its representativeness and validity. However, modifications were made to include relevant issues like climate change and renewable energy, thereby creating an enhanced National Vision to 2030.',
#           'document_id': 2530,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'drRI1X8B6OZKDs8-_JOX',
#          '_score': 82.27734,
#          '_source': {'document_name': 'full text (PDF)',
#           'country_code': 'TTO',
#           'action_id': 2018,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p128_b2329',
#           'action_date': '25/12/2016',
#           'text': 'national development plan',
#           'document_id': 2530,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'pLRI1X8B6OZKDs8-8oqh',
#          '_score': 82.04491,
#          '_source': {'document_name': 'full text (PDF)',
#           'country_code': 'TTO',
#           'action_id': 2018,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p13_b71',
#           'action_date': '25/12/2016',
#           'text': 'economic prosperity.  Through the adoption of a comprehensive national development planning framework, this National Development Strategy (NDS) 2016-2030, Vision 2030, will lay the foundation and pathway for attaining developed country status by the year 2030.  Vision 2030 builds on the principles, mission and processes of Vision 2020 that resulted from extensive dialogue with civil society, academia, the private sector and the public sector, culminating in over 80 consultations. To date, this record stands unchallenged and this extensive and inclusive work has laid a solid foundation for preparing the Vision 2030 Strategy. In addition, the NDS also takes cognizance of developments that would have occurred up to 2015.',
#           'document_id': 2530,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'tLRI1X8B6OZKDs8-8oqh',
#          '_score': 81.99669,
#          '_source': {'document_name': 'full text (PDF)',
#           'country_code': 'TTO',
#           'action_id': 2018,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p15_b87',
#           'action_date': '25/12/2016',
#           'text': 'rinidad and Tobago is now in such a time as falling energy prices and revenues are threatening our standard of living and our way of life. In response, the Draft National Development Strategy (NDS) 2016-2030 (Vision 2030) was developed, which incorporates the principles and objectives of the Sustainable Development Goals (SDGs). It aims to guide the development process taking into consideration the immediate and future needs of all our citizens. As the country’s sustainable development strategy, the NDS establishes the vision and broad framework for Trinidad and Tobago’s development to 2030 and defines the key priorities for the first planning period 2016-2020. Moreover, the NDS posits that bold steps have to be taken by all segments of society towards making the socio-economic transformations that are needed to surmount our many developmental and environmental challenges. This document contains six (6) chapters of which the key elements are presented as follows.',
#           'document_id': 2530,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'prRI1X8B6OZKDs8-8oqh',
#          '_score': 81.979515,
#          '_source': {'document_name': 'full text (PDF)',
#           'country_code': 'TTO',
#           'action_id': 2018,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p14_b73',
#           'action_date': '25/12/2016',
#           'text': 'goals, and the national short-term goals and strategies over the next five years (2016–2020) to lay the foundation for achieving the vision over the longer period. The draft Strategy will also start the dialogue on the cultural and the behavioural shifts that are regarded as requisites for further development. It is important to note that the formulation of the NDS draws on the Comprehensive Economic Development Plan (CEDP) for Tobago (2013‒2017) which itself was grounded in the context of Vision 2020.',
#           'document_id': 2530,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'X7RI1X8B6OZKDs8-9I33',
#          '_score': 81.58569,
#          '_source': {'document_name': 'full text (PDF)',
#           'country_code': 'TTO',
#           'action_id': 2018,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p47_b770',
#           'action_date': '25/12/2016',
#           'text': 'Further, The National Population and Development Policy (NPDP) 2014‒2020 highlighted the importance of planning for demographic changes based on other data trends revealed in the 2011 population cen',
#           'document_id': 2530,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'KbRI1X8B6OZKDs8-8ouh',
#          '_score': 81.49736,
#          '_source': {'document_name': 'full text (PDF)',
#           'country_code': 'TTO',
#           'action_id': 2018,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p18_b204',
#           'action_date': '25/12/2016',
#           'text': 'NATIONAL DEVELOPMENT STRATEGY 2016-2030',
#           'document_id': 2530,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '77RI1X8B6OZKDs8-_pTU',
#          '_score': 81.24892,
#          '_source': {'document_name': 'full text (PDF)',
#           'country_code': 'TTO',
#           'action_id': 2018,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p144_b2706',
#           'action_date': '25/12/2016',
#           'text': 'ety and international development agencies. As a result, over 80 consultations were held across the length and breadth of Trinidad and Tobago. The process produced 27 sub-committee reports and the final product: the Vision 2020 National Strategic Plan.',
#           'document_id': 2530,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'UbRI1X8B6OZKDs8-8ouh',
#          '_score': 80.90982,
#          '_source': {'document_name': 'full text (PDF)',
#           'country_code': 'TTO',
#           'action_id': 2018,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p20_b244',
#           'action_date': '25/12/2016',
#           'text': 'This National Development Strategy 2016‒2030, aims to address the development issues presented above and establish the foun',
#           'document_id': 2530,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'PrRI1X8B6OZKDs8--pAi',
#          '_score': 80.403435,
#          '_source': {'document_name': 'full text (PDF)',
#           'country_code': 'TTO',
#           'action_id': 2018,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p71_b1505',
#           'action_date': '25/12/2016',
#           'text': 'ment Goals comprises short-, medium- and long-term goals to coincide with three 5-year planning periods between 2016 and 2030, which are: 2016-2020; 2021-2025; and 2026-2030. The short- and medium-term goals all coalesce towards meeting the long-term goals which in turn, reflect the outcomes of the five Development Themes. There are 16 long-term goals that span 2016-2030, 16 medium-term goals that span 2016-2025 and 24 short-term goals that span 2016-2020.',
#           'document_id': 2530,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}}]}}},
#     {'key': '2591',
#      'doc_count': 10,
#      'top_hit': {'value': 82.67594909667969},
#      'top_passage_hits': {'hits': {'total': {'value': 10, 'relation': 'eq'},
#        'max_score': 82.67595,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'MLRI1X8B6OZKDs8-_pXU',
#          '_score': 82.67595,
#          '_source': {'document_name': 'Link to December 2019 framework paper',
#           'country_code': 'UGA',
#           'action_id': 2065,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p1_b1',
#           'action_date': '12/01/2019',
#           'text': 'National Budget Framework Paper FY 2020/21',
#           'document_id': 2591,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'NbRI1X8B6OZKDs8-_pXU',
#          '_score': 82.67595,
#          '_source': {'document_name': 'Link to December 2019 framework paper',
#           'country_code': 'UGA',
#           'action_id': 2065,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p2_b1',
#           'action_date': '12/01/2019',
#           'text': 'National Budget Framework Paper FY 2020/21',
#           'document_id': 2591,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'U7RI1X8B6OZKDs8-_pXU',
#          '_score': 82.67595,
#          '_source': {'document_name': 'Link to December 2019 framework paper',
#           'country_code': 'UGA',
#           'action_id': 2065,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p3_b1',
#           'action_date': '12/01/2019',
#           'text': 'National Budget Framework Paper FY 2020/21',
#           'document_id': 2591,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'MrRI1X8B6OZKDs8-_pXU',
#          '_score': 81.89264,
#          '_source': {'document_name': 'Link to December 2019 framework paper',
#           'country_code': 'UGA',
#           'action_id': 2065,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p1_b3',
#           'action_date': '12/01/2019',
#           'text': 'NATIONAL\nBUDGET FRAMEWORK PAPER\nFY 2020/21 – FY 2024/25',
#           'document_id': 2591,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'ULRI1X8B6OZKDs8-_pXU',
#          '_score': 5.7165008,
#          '_source': {'document_name': 'Link to December 2019 framework paper',
#           'country_code': 'UGA',
#           'action_id': 2065,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p2_b28',
#           'action_date': '12/01/2019',
#           'text': '1.8\nBUDGET STRATEGY FY 2020/21 ................................................................................................ xix',
#           'document_id': 2591,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'SrRI1X8B6OZKDs8-_pXU',
#          '_score': 5.557144,
#          '_source': {'document_name': 'Link to December 2019 framework paper',
#           'country_code': 'UGA',
#           'action_id': 2065,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p2_b22',
#           'action_date': '12/01/2019',
#           'text': '1.4.1 RESOURCE ENVELOPE FOR FY 2020/21 ............................................................................. xiii',
#           'document_id': 2591,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'UbRI1X8B6OZKDs8-_pXU',
#          '_score': 5.557144,
#          '_source': {'document_name': 'Link to December 2019 framework paper',
#           'country_code': 'UGA',
#           'action_id': 2065,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p2_b29',
#           'action_date': '12/01/2019',
#           'text': '1.8.1 Sectoral Priorities for FY 2020/21 ............................................................................................... xix',
#           'document_id': 2591,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'S7RI1X8B6OZKDs8-_pXU',
#          '_score': 5.4064302,
#          '_source': {'document_name': 'Link to December 2019 framework paper',
#           'country_code': 'UGA',
#           'action_id': 2065,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p2_b23',
#           'action_date': '12/01/2019',
#           'text': '1.5\nDEBT FINANCING STRATEGY FOR FY 2020/21 .................................................................... xiv',
#           'document_id': 2591,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'M7RI1X8B6OZKDs8-_pXU',
#          '_score': 3.2804172,
#          '_source': {'document_name': 'Link to December 2019 framework paper',
#           'country_code': 'UGA',
#           'action_id': 2065,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p1_b4',
#           'action_date': '12/01/2019',
#           'text': 'MINISTRY OF FINANCE, PLANNING AND\nECONOMIC DEVELOPMENT',
#           'document_id': 2591,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'L7RI1X8B6OZKDs8-_pXU',
#          '_score': 1.0017078,
#          '_source': {'document_name': 'Link to December 2019 framework paper',
#           'country_code': 'UGA',
#           'action_id': 2065,
#           'action_source_name': 'CCLW',
#           'action_date': '12/01/2019',
#           'description': 'This budget law notably aims to provide relief aid in response to disasters, including climate-induced floods and landslides. The budget framework paper also sets targets of forest cover, integration of the climate change issue into development plans, and change in direct and indirect GHG emissions.',
#           'document_id': 2591,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}}]}}},
#     {'key': '2090',
#      'doc_count': 114,
#      'top_hit': {'value': 81.8805923461914},
#      'top_passage_hits': {'hits': {'total': {'value': 114, 'relation': 'eq'},
#        'max_score': 81.88059,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 't7RI1X8B6OZKDs8-wmQS',
#          '_score': 81.88059,
#          '_source': {'document_name': 'Full text document',
#           'country_code': 'RWA',
#           'action_id': 1662,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p6_b7',
#           'action_date': '01/01/2017',
#           'text': 'The development landscape in Rwanda has changed considerably since the adoption of the Vision 2020 in the year 2000. The progress made in less than two decades has given Rwandans much hope and belief to aspire for greater achievements. The National Strategy for Transformation (NST1) which is also the Seven Year Government Programme (7YGP) comes at a unique moment in the country’s development trajectory which will see the crossover from Vision 2020 towards Vision 2050. This strategy is expected to lay the foundation for decades of sustained growth and transformation that will accelerate the move towards achieving high standards of living for all Rwandans.',
#           'document_id': 2090,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'RrRI1X8B6OZKDs8-xGVu',
#          '_score': 81.86282,
#          '_source': {'document_name': 'Full text document',
#           'country_code': 'RWA',
#           'action_id': 1662,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p13_b150',
#           'action_date': '01/01/2017',
#           'text': 'NST1 merges the 7 Year Government Program (2017-2024) and the national medium term development strategy, which were previously standalone documents.',
#           'document_id': 2090,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'MbRI1X8B6OZKDs8-xGVu',
#          '_score': 78.776566,
#          '_source': {'document_name': 'Full text document',
#           'country_code': 'RWA',
#           'action_id': 1662,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p13_b129',
#           'action_date': '01/01/2017',
#           'text': 'NST1 builds on lessons learned, successes and challenges encountered in previous medium term development strategies. It therefore entails interventions to enable the transformation journey towards achieving Vision 2050 aspirations.',
#           'document_id': 2090,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '-7RI1X8B6OZKDs8-xGZu',
#          '_score': 9.388033,
#          '_source': {'document_name': 'Full text document',
#           'country_code': 'RWA',
#           'action_id': 1662,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p34_b587',
#           'action_date': '01/01/2017',
#           'text': 'and one branch per Province will be established to foster a mindset that accelerates development and national self-reliance.',
#           'document_id': 2090,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'UrRI1X8B6OZKDs8-xGVu',
#          '_score': 8.560579,
#          '_source': {'document_name': 'Full text document',
#           'country_code': 'RWA',
#           'action_id': 1662,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p14_b162',
#           'action_date': '01/01/2017',
#           'text': 'home-Grown Solutions',
#           'document_id': 2090,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'D7RI1X8B6OZKDs8-xGZu',
#          '_score': 7.2997265,
#          '_source': {'document_name': 'Full text document',
#           'country_code': 'RWA',
#           'action_id': 1662,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p23_b351',
#           'action_date': '01/01/2017',
#           'text': 'Promote new models of irrigation scheme management,',
#           'document_id': 2090,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'W7RI1X8B6OZKDs8-xmfH',
#          '_score': 7.007631,
#          '_source': {'document_name': 'Full text document',
#           'country_code': 'RWA',
#           'action_id': 1662,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p38_b683',
#           'action_date': '01/01/2017',
#           'text': 'interact with citizens on the national development agenda.',
#           'document_id': 2090,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'BrRI1X8B6OZKDs8-xGZu',
#          '_score': 6.9037805,
#          '_source': {'document_name': 'Full text document',
#           'country_code': 'RWA',
#           'action_id': 1662,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p22_b342',
#           'action_date': '01/01/2017',
#           'text': 'operationalize long-term savings scheme and pension for all',
#           'document_id': 2090,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'wrRI1X8B6OZKDs8-wmQS',
#          '_score': 6.8139033,
#          '_source': {'document_name': 'Full text document',
#           'country_code': 'RWA',
#           'action_id': 1662,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p7_b18',
#           'action_date': '01/01/2017',
#           'text': 'Rwanda adopted its Vision 2020 in the year 2000. Through a succession of poverty reduction and economic development strategies, Rwanda has developed the necessary policies and tools for attaining Vision 2020 aspirations',
#           'document_id': 2090,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'B7RI1X8B6OZKDs8-xGZu',
#          '_score': 6.7137456,
#          '_source': {'document_name': 'Full text document',
#           'country_code': 'RWA',
#           'action_id': 1662,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p22_b343',
#           'action_date': '01/01/2017',
#           'text': 'Rwandans including those in the informal sector as a basis to support long-term domestic investments. The scheme aims to have at least 700,000 subscribers by 2024. The scheme will eventually be leveraged by beneficiaries to save for housing, investment and child education. Long term investment funds will be expanded through mobilization and investment of Agaciro Development Fund (AgDF) as well as promotion of collective investment schemes through Rwanda National Investment Trust (RNIT).',
#           'document_id': 2090,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}}]}}},
#     {'key': '2408',
#      'doc_count': 155,
#      'top_hit': {'value': 81.07270812988281},
#      'top_passage_hits': {'hits': {'total': {'value': 155, 'relation': 'eq'},
#        'max_score': 81.07271,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'drRI1X8B6OZKDs8-3Hqb',
#          '_score': 81.07271,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'SUR',
#           'action_id': 1921,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p22_b197',
#           'action_date': '30/10/2019',
#           'text': 'The National Development Plan (GOS 2017) anticipates the phased elimination of round wood exports and \nthe increase of national value added to forest products. This would promote economic diversification and \nbenefit local and national employment.',
#           'document_id': 2408,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'hrRI1X8B6OZKDs8-3Hqb',
#          '_score': 79.66803,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'SUR',
#           'action_id': 1921,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p23_b213',
#           'action_date': '30/10/2019',
#           'text': 'At the policy level, this strategic line is related to the National Development Plan 2017- 2021, which \nunderscores the integration of national and regional development planning to facilitate the sustainable use \nand management of forests. Furthermore, strengthening of the regulatory and supervisory institutions and \nthe involvement of the local population are key principles in this regard.',
#           'document_id': 2408,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'ErRI1X8B6OZKDs8-3Hqb',
#          '_score': 79.35332,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'SUR',
#           'action_id': 1921,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p12_b97',
#           'action_date': '30/10/2019',
#           'text': 'REDD+ can support this development process and can be seen as a pillar of a climate compatible development \nstrategy within a path that balances social, economic and environmental priorities and objectives, and can \nbe used as a planning tool for the sustainable development of the interior in the integrative vision of its \ndevelopment process (GOS 2013). For this, market potential of different diversification options need to be \nanalysed. The Local Economic Development (LEO) strategic approach of the National Development Plan \n2017 – 2021 aims at sustainable economic growth by means of increased participation and public and private \npartnerships, strengthening the development capacity of small isolated communities in the interior, including \nsmall businesses, local administrative bodies and the networks of their organizations for their advance and \ndevelopment.',
#           'document_id': 2408,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'PbRI1X8B6OZKDs8-3Hqb',
#          '_score': 79.05981,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'SUR',
#           'action_id': 1921,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p17_b140',
#           'action_date': '30/10/2019',
#           'text': 'As stated above, a key element of the implementation strategy for the National Development Plan 2017-2021 \nis to enhance participation of stakeholders in policy formulation and implementation. According to the Plan,',
#           'document_id': 2408,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'ILRI1X8B6OZKDs8-3Hqb',
#          '_score': 78.56129,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'SUR',
#           'action_id': 1921,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p14_b111',
#           'action_date': '30/10/2019',
#           'text': 'The provision of alternative livelihoods for forest dependent communities could reduce pressures and \ndamages by deforestation and forest degradation due to unsustainable uses of the forest resource. The \nNational Development Plan 2017-2021 gives significant priority to what it calls the Production Cluster Tourism, \nand highlights the country’s natural and cultural attributes for this purpose. Several concrete objectives \nare defined, including the implementation of the strategic development plan for the Tourism and Creative \nIndustry, arrangement of new commercial flight connections, preparation of a Tourism Master Plan and the \nestablishment of a Suriname Tourism Authority, among other actions.',
#           'document_id': 2408,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'sLRI1X8B6OZKDs8-33og',
#          '_score': 76.14723,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'SUR',
#           'action_id': 1921,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p26_b255',
#           'action_date': '30/10/2019',
#           'text': 'The new land use planning legislation should provide for an improved coordination mechanism and \nconsultation and participation with non-state actors, mandatory and accountable spatial plans, as well as \nconsistency in hierarchy of plans (national to local, also considering community plans).',
#           'document_id': 2408,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'rrRI1X8B6OZKDs8-33og',
#          '_score': 76.14218,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'SUR',
#           'action_id': 1921,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p26_b253',
#           'action_date': '30/10/2019',
#           'text': 'Measure 3.B.4: Formulate new land use planning legislation to ensure harmonization of sectoral \nlegislation and enhance the coordinating role of the Ministry of RGB as institution to lead the land use \nplanning processes at the national level through institutional strengthening of the Ministry',
#           'document_id': 2408,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '-LRI1X8B6OZKDs8-33og',
#          '_score': 8.625433,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'SUR',
#           'action_id': 1921,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p33_b327',
#           'action_date': '30/10/2019',
#           'text': 'One of the objectives of the National Development Plan 2017-2021 in the area of Forestry is the promotion \nof scientific research to improve forest use (GOS 2017). The National Forest Policy recognizes the importance \nof research as a supporting element for the development of the sector. At that time (2006) a broadly based \nnational forest research agenda was lacking (GOS 2006). The National Development Plan also identifies \ndevelopment capacity strengthening as one of the four pillars, recognizing the importance of human capacities \nin the development potential, including in the area of forest management.',
#           'document_id': 2408,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '7LRI1X8B6OZKDs8-33og',
#          '_score': 7.454263,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'SUR',
#           'action_id': 1921,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p32_b315',
#           'action_date': '30/10/2019',
#           'text': 'Within the context of the REDD+ Program, and as outlined by the National Development Plan 2017-2021 \n(GOS 2017), the mangrove forests that protect the Atlantic coastline will be protected within a scheme \ncoupled with improved land zoning and enforcement capacities.',
#           'document_id': 2408,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '3bRI1X8B6OZKDs8-33og',
#          '_score': 7.028226,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'SUR',
#           'action_id': 1921,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p31_b300',
#           'action_date': '30/10/2019',
#           'text': 'This strategic line is related to the National Biodiversity Action Plan (NBAP) and to the National Forest \nPolicy. The NBAP states as one of its objectives the',
#           'document_id': 2408,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}}]}}},
#     {'key': '2407',
#      'doc_count': 528,
#      'top_hit': {'value': 80.89706420898438},
#      'top_passage_hits': {'hits': {'total': {'value': 528, 'relation': 'eq'},
#        'max_score': 80.897064,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'LLRI1X8B6OZKDs8-03IT',
#          '_score': 80.897064,
#          '_source': {'document_name': 'Full text (part I) - PDF',
#           'country_code': 'SUR',
#           'action_id': 1920,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p48_b682',
#           'action_date': '25/12/2017',
#           'text': 'Based on the above it is clear that within short, drastic measures are necessary to increase the development capacity. However, the building of an actual national planning capacity is a long process and short-term measures, especially in this area, may not undermine the chances for longer-term success (see also Appendix 2: points of departure for the rebuilding of the National Planning Machinery). The development goal for the National Planning Machinery is as follows:',
#           'document_id': 2407,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'YrRI1X8B6OZKDs8-03ET',
#          '_score': 80.229324,
#          '_source': {'document_name': 'Full text (part I) - PDF',
#           'country_code': 'SUR',
#           'action_id': 1920,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p38_b480',
#           'action_date': '25/12/2017',
# ...
#           'document_id': 1353,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'aLRI1X8B6OZKDs8-sFfM',
#          '_score': 5.9192114,
#          '_source': {'document_name': 'Full text of the plan',
#           'country_code': 'KGZ',
#           'action_id': 1062,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p15_b231',
#           'action_date': '13/04/2013',
#           'text': 'level of one-digit',
#           'document_id': 1353,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}}]}}},
#     {'key': '2455',
#      'doc_count': 200,
#      'top_hit': {'value': 78.33578491210938},
#      'top_passage_hits': {'hits': {'total': {'value': 200, 'relation': 'eq'},
#        'max_score': 78.335785,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'P7RI1X8B6OZKDs8-6ITY',
#          '_score': 78.335785,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1948,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p26_b835',
#           'action_date': '28/01/2021',
#           'text': "Figure 8: Development of power generation by technology according to the ZERO basis scenario of the EP2050+ (strategy variant 'balanced annual performance 2050', nuclear power plant term: 50 years). Source: Prognos/TEP Energy/Infras/Ecoplan (2020)",
#           'document_id': 2455,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'B7RI1X8B6OZKDs8-6IPY',
#          '_score': 77.94468,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1948,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p18_b523',
#           'action_date': '28/01/2021',
#           'text': "tribution in this respect. The 'MuKEn' and their future development will also create incentives for replacing existing buildings that no longer meet the future requirements with new ones that comply with the current standards. This will also create opportunities for urban densification, the moderni-",
#           'document_id': 2455,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'xrRI1X8B6OZKDs8-7Ye5',
#          '_score': 77.93285,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1948,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p54_b1738',
#           'action_date': '28/01/2021',
#           'text': "Figure 30: Development of annualised investments, operating and maintenance costs and energy cost savings in the ZERO basis scenario of the EP2050+ (in million CHF, difference compared to the 'Business as usual' scenario, excluding international aviation). Source: Prognos/TEP Energy/Infras/Ecoplan 2020.",
#           'document_id': 2455,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'Y7RI1X8B6OZKDs8-64RL',
#          '_score': 77.77052,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1948,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p28_b871',
#           'action_date': '28/01/2021',
#           'text': 'is set to fall by around 35 per cent in new single and multi-family homes in comparison with 2020–50, according to the EP2050+. Progress on a similar scale is required for renovations. Figure 11 (right) also shows the proportionally dominant role of heating supply long-term and also its decline (in absolute terms) compared to today. There is increasing energy demand mainly in the areas of air-con',
#           'document_id': 2455,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'bbRI1X8B6OZKDs8-6IPY',
#          '_score': 77.678085,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1948,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p19_b625',
#           'action_date': '28/01/2021',
#           'text': 'house-gas-free transport in view of the development beyond 2030 already defined. Compliance with',
#           'document_id': 2455,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'ZrRI1X8B6OZKDs8-64RL',
#          '_score': 77.49867,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1948,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p28_b874',
#           'action_date': '28/01/2021',
#           'text': "Renovation work must significantly increase over the coming years in order to replace fossil energies quickly and fully. The frequency for energy-related renovations of building components (windows, fa-çade, roof and flooring) then also increases significantly in the ZERO basis scenario. The renovation rates in old building stock are 30 to 50 per cent higher than in the 'Business as usual' scenario. The renovation rate for single-family homes rises to around 1.4 per cent a year by 2040 in old housing stock. The rate then stands at 1.2 per cent a year for the entire housing stock. For multi-family homes, the rate in old housing stock stands at 1.6 per cent a year (1.2 per cent a year for the entire housing stock). The level of renovation also changes in parallel with renovation frequency. The consumption of extensively renovated buildings falls to 50 kWh/m",
#           'document_id': 2455,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'NbRI1X8B6OZKDs8-6ITY',
#          '_score': 77.18012,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1948,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p25_b825',
#           'action_date': '28/01/2021',
#           'text': 'The EP2050+ shows the development of power supply in the context of the net-zero target (ZERO basis scenario). The second key framework condition – in addition to the net-zero target – is ensuring secure power supply at all times in future. The long-term development of demand for power is influenced by two opposing effects. On one hand, the technical progress and the measures taken result in tangible efficiency improvements, reducing demand for electricity. On the other, there are developments resulting in greater demand for power, in particular the market penetration of electric vehicles and heat pumps as well as the production of electricity-based energies, such as hydrogen, and the deployment of CCS.',
#           'document_id': 2455,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'PLRI1X8B6OZKDs8-64ZL',
#          '_score': 76.953804,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1948,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p42_b1344',
#           'action_date': '28/01/2021',
#           'text': 'In the 2020 climate compatibility test, pension funds indicated that they are carrying out conversion from fossil energy to renewable heating systems for 30 per cent of their buildings. Overall, 70 per cent of the buildings tested were still heated with oil and gas, while the figure was as high as around 80 per cent for mortgaged properties.',
#           'document_id': 2455,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'CrRI1X8B6OZKDs8-6ITY',
#          '_score': 76.63846,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1948,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p23_b782',
#           'action_date': '28/01/2021',
#           'text': 'Act completed in 2020, which were still undergoing parliamentary consultation when the scenarios were being drawn up, are not included in the scenarios. The comparison of this scenario with the net-zero scenario reveals the need for additional action required for target attainment by 2050 under the assumptions made. Ad',
#           'document_id': 2455,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'fbRI1X8B6OZKDs8-7Ye5',
#          '_score': 76.61015,
#          '_source': {'document_name': 'Link to full text (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1948,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p50_b1665',
#           'action_date': '28/01/2021',
#           'text': 'lenges. This requires the involvement of various actors and the use of targeted regulatory incentives. It is therefore advisable to aim to achieve the development required to meet the net-zero objective using two targets: with a reduction pathway for the greenhouse gas emissions and a target (or a development pathway) for the negative emissions (including CCS contributions where applicable). This separate ap',
#           'document_id': 2455,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}}]}}},
#     {'key': '2454',
#      'doc_count': 18,
#      'top_hit': {'value': 78.19625854492188},
#      'top_passage_hits': {'hits': {'total': {'value': 18, 'relation': 'eq'},
#        'max_score': 78.19626,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'gLRI1X8B6OZKDs8-5oBv',
#          '_score': 78.19626,
#          '_source': {'document_name': 'Full document (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1947,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p11_b113',
#           'action_date': '25/12/2018',
#           'text': 'With effect from 2031, no new investment contributions / \none-time remuneration',
#           'document_id': 2454,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'cLRI1X8B6OZKDs8-5IAE',
#          '_score': 75.6914,
#          '_source': {'document_name': 'Full document (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1947,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p8_b97',
#           'action_date': '25/12/2018',
#           'text': 'Timeframe: For the duration of market \npremium for large hydropower plants \n(2018 to 2022), i.e. reduced one-time \nremuneration, geothermal energy \ncontributions, investment contributions for \nsmall hydropower plants and biomass',
#           'document_id': 2454,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'r7RI1X8B6OZKDs8-5oBv',
#          '_score': 74.00375,
#          '_source': {'document_name': 'Full document (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1947,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p16_b160',
#           'action_date': '25/12/2018',
#           'text': 'Modification of “Buildings” programme',
#           'document_id': 2454,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'arRI1X8B6OZKDs8-5IAE',
#          '_score': 72.618904,
#          '_source': {'document_name': 'Full document (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1947,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p7_b91',
#           'action_date': '25/12/2018',
#           'text': 'Network surcharge for promotion of electricity from \nrenewable energy, energy efficiency and \nimprovement of quality of bodies of water',
#           'document_id': 2454,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'crRI1X8B6OZKDs8-5IAE',
#          '_score': 72.49999,
#          '_source': {'document_name': 'Full document (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1947,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p9_b99',
#           'action_date': '25/12/2018',
#           'text': 'Repeal of requirement to use part of refunded network \nsurcharge for energy-efficiency measures',
#           'document_id': 2454,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'ILRI1X8B6OZKDs8-5IAE',
#          '_score': 72.32893,
#          '_source': {'document_name': 'Full document (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1947,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p2_b17',
#           'action_date': '25/12/2018',
#           'text': 'Federal Council adopts Dispatch \nto Parliament on new Energy Act',
#           'document_id': 2454,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'WrRI1X8B6OZKDs8-5IAE',
#          '_score': 6.4571657,
#          '_source': {'document_name': 'Full document (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1947,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p5_b75',
#           'action_date': '25/12/2018',
#           'text': '-16% in 2020',
#           'document_id': 2454,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'XrRI1X8B6OZKDs8-5IAE',
#          '_score': 6.4571657,
#          '_source': {'document_name': 'Full document (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1947,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p5_b79',
#           'action_date': '25/12/2018',
#           'text': '-3% in 2020',
#           'document_id': 2454,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'YrRI1X8B6OZKDs8-5IAE',
#          '_score': 6.4571657,
#          '_source': {'document_name': 'Full document (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1947,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p6_b83',
#           'action_date': '25/12/2018',
#           'text': 'in 2020: 4’400',
#           'document_id': 2454,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'v7RI1X8B6OZKDs8-5oBv',
#          '_score': 5.8852673,
#          '_source': {'document_name': 'Full document (PDF)',
#           'country_code': 'CHE',
#           'action_id': 1947,
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p18_b176',
#           'action_date': '25/12/2018',
#           'text': '/km by the end of 2020',
#           'document_id': 2454,
#           'document_language_id': 1826.0,
#           'action_type_name': 'Policy'}}]}}}]}}}
