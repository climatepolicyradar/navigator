# %% [markdown]
# # Opensearch 'semantic search' query
#
# Requirements:
# - [ ] fuzzy text + KNN search in summaries and full text
# - [ ] fuzzy text search on titles (with priority given to exact matches)
# - [ ] fields are given priority in the following order: title > summary > text
# - [ ] search is case-insensitive
# - [ ] out-of-word punctuation is ignored. E.g. 'electricity!' == 'electricity'.
# - [ ] number of matching passages and documents is returned.
# - [ ] a user can sort by date and title, ascending or descending.

# %%
# %load_ext autoreload
# %autoreload 2

import time
import numpy as np
from typing import Optional, List, Dict, Tuple

from app.index import OpenSearchIndex
from app.ml import SBERTEncoder
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1a. Connect to Opensearch
# As we're outside of docker-compose we'll connect to Opensearch via localhost.

# %%
opensearch = OpenSearchIndex(
    url="http://localhost:9200",
    username="admin",
    password="admin",
    index_name="navigator",
    # TODO: convert to env variables?
    opensearch_connector_kwargs={
        "use_ssl": False,
        "verify_certs": False,
        "ssl_show_warn": False,
    },
    embedding_dim=768,
)

print(opensearch.is_connected())

opns = opensearch.opns
# Out:
# True

# %% [markdown]
# ### 1b. Load sentence-BERT encoder
#
# This is used to generate embeddings for semantic search.

# %%
# TODO: this needs to be the same model as used for indexing. At a later stage when we start updating 
# models we may want a way of ensuring both models are the same.
enc = SBERTEncoder(model_name="msmarco-distilbert-dot-v5")
enc.encode("hello world").shape
# Out:
# (768,)

# %%
emba = enc.encode("bicycle race")
embb = enc.encode("car race")
embc = enc.encode("tortoise race")

np.dot(emba, embb), np.dot(emba, embc)
# Out:
# (80.994026, 76.67018)

# %% [markdown]
# ### 2. Run search
#
# The `run_query` function does all of the heavy lifting here.

# %%
def _innerproduct_threshold_to_lucene_threshold(ip_thresh: float) -> float:
    """
    Opensearch documentation on mapping similarity functions to Lucene thresholds is here: https://github.com/opensearch-project/k-NN/blob/main/src/main/java/org/opensearch/knn/index/SpaceType.java#L33
    It defines 'inner product' as negative inner product i.e. a distance rather than similarity measure, so we reverse the signs of inner product here compared to the docs.
    """
    if ip_thresh > 0:
        return ip_thresh + 1
    else:
        return 1 / (1-ip_thresh)

def _year_range_filter(year_range: Tuple[Optional[int], Optional[int]]):
    """
    Get an Opensearch filter for year range. The filter returned is between the first term of
    `year_range` and the last term, and is inclusive. Either value can be set to None to only
    apply one year constraint.
    """

    start_date = f"01/01/{year_range[0]}" if year_range[0] is not None else None
    end_date = f"31/12/{year_range[1]}" if year_range[1] is not None else None

    policy_year_conditions = {}
    if start_date is not None:
        policy_year_conditions["gte"] = start_date
    if end_date is not None:
        policy_year_conditions["lte"] = end_date

    range_filter = {"range": {}}

    range_filter["range"]["action_date"] = policy_year_conditions

    return range_filter
    

def run_query(
    query: str, 
    max_passages_per_doc: int, 
    keyword_filters: Optional[Dict[str, List[str]]] = None, 
    year_range: Optional[Tuple[Optional[int], Optional[int]]] = None,
    sort_field: Optional[str] = None,
    sort_order: Optional[str] = None,
    innerproduct_threshold: float = 70,
) -> dict:
    """
    Run an Opensearch query.
    
    Args:
        query (str): query string
        innerproduct_threshold (float): threshold applied to KNN results
        max_passages_per_doc (int): maximum number of passages to return per document
        keyword_filters (Optional[Dict[str, List[str]]]): filters on keyword values to apply.
        In the format `{"field_name": ["values", ...], ...}`. Defaults to None.
        year_range (Optional[Tuple[Optional[int], Optional[int]]]): filter on action year by (minimum, maximum). 
        Either value can be set to `None` for a one-sided filter.
        sort_field (Optional[str]): field to sort. Only the values `action_date`, `action_name` or `None` are valid.
        sort_order (Optional[str]): order to sort in, applied if `sort_field` is not None. Can be either "asc" or "desc".
    
    Returns:
        dict: raw Opensearch result.
    """
    
    embedding = enc.encode(query)
    lucene_threshold = _innerproduct_threshold_to_lucene_threshold(innerproduct_threshold)

    opns_query = {
                "size": 0, # only return aggregations
                "query": {
                    "bool": {
                        "should": [
                            {
                                "bool": {
                                    "should": [
                                        {
                                            "match": {
                                                "text": {
                                                    "query": query,
                                                },
                                            }
                                        },
                                        {
                                            "function_score": {
                                                "query": {
                                                    "knn": {
                                                        "text_embedding": {
                                                            "vector": embedding,
                                                            "k": 10000, # TODO: tune me
                                                        },
                                                    },
                                                },
                                                "min_score": lucene_threshold
                                            }
                                        },
                                    ],
                                    "minimum_should_match": 1,
                                }
                            },
                            {
                                "bool": {
                                    "should": [
                                        {
                                            "match": {
                                                "for_search_action_description": {
                                                    "query": query,
                                                    "boost": 3,
                                                }
                                            }
                                        },
                                        {
                                            "function_score": {
                                                "query": {
                                                    "knn": {
                                                        "action_description_embedding": {
                                                            "vector": embedding,
                                                            "k": 10000, # TODO: tune me
                                                        },
                                                    },
                                                },
                                                "min_score": lucene_threshold # TODO: tune me separately for descriptions?
                                            }
                                        },
                                        # TODO: add knn on action description
                                    ],
                                    "minimum_should_match": 1,
                                    "boost": 2
                                },
                            },
                            {
                                "bool": {
                                    "should": [
                                        {
                                            "match": {
                                                "for_search_action_name": {
                                                    "query": query,
                                                }
                                            }
                                        },
                                        {
                                            "match_phrase": {
                                                "for_search_action_name": {
                                                    "query": query,
                                                    "boost": 2,
                                                }
                                            }
                                        },
                                    ],
                                    "boost": 10,
                                }
                            }
                        ],
                        "minimum_should_match": 1
                    },
                },
                "aggs": {
                    "top_docs": {
                        "terms": {
                            "field": "action_name_and_id",
                            "order": {"top_hit": "desc"},
                            "size": 100,
                        },
                        "aggs": {
                            "top_passage_hits": {
                                "top_hits": {
                                    "_source": {"excludes": ["text_embedding", "action_description_embedding"]},
                                    "size": max_passages_per_doc,
                                }
                            },
                            "top_hit": {"max": {"script": {"source": "_score"}}},
                            "action_date": {
                                "stats": {
                                    "field": "action_date"
                                }
                            }
                        },
                    },
                    "bucketcount": {
                      "stats_bucket": {
                        "buckets_path": "top_docs._count"
                      }
                    }
                },
            }
    
    if keyword_filters:
        terms_clauses = []

        for field, values in keyword_filters.items():
            terms_clauses.append({"terms": {field: values}})

        opns_query["query"]["bool"]["filter"] = terms_clauses

    
    if year_range:
        if "filter" not in opns_query["query"]["bool"]:
            opns_query["query"]["bool"]["filter"] = []

        opns_query["query"]["bool"]["filter"].append(
            _year_range_filter(year_range)
        )
        
    # TODO: how does this work in a situation with more than 10,000 i.e. paginated results?
    if sort_field and sort_order:
        if sort_field == "action_date":
            opns_query["aggs"]["top_docs"]["terms"]["order"] = {f"{sort_field}.avg": sort_order}
        elif sort_field == "action_name":
            opns_query["aggs"]["top_docs"]["terms"]["order"] = {"_key": sort_order}
    
    start = time.time()
    response = opns.search(
        body=opns_query,
        index="navigator",
        request_timeout=30,
        preference="prototype_user", # TODO: document what this means
        explain=True,
    )
    end = time.time()
    
    passage_hit_count = response['hits']['total']['value']
    # note: 'gte' values are returned when there are more than 10,000 results by default
    if response['hits']['total']['relation'] == "eq":
        passage_hit_qualifier = "exactly"
    elif response['hits']['total']['relation'] == "gte":
        passage_hit_qualifier = "at least"
    
    doc_hit_count = response['aggregations']['bucketcount']['count']
    
    print(f"query execution time: {round(end-start, 2)}s")
    print(f"returned {passage_hit_qualifier} {passage_hit_count} passage(s) in {doc_hit_count} document(s)")
    
    return response

# TODO: we should experimentally adjust this threshold 
response = run_query(
    "restaurant sustainability", 
    max_passages_per_doc=10,
    # year_range=(2000, None),
    # keyword_filters={
    #     "action_country_code": ["CHE"]
    # },
    # sort_field = "action_name",
    # sort_order = "asc",
    innerproduct_threshold=70, # TODO: tune me
)

response
# Out:
# query execution time: 0.67s
# returned exactly 519 passage(s) in 38 document(s)
# {'took': 620,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 519, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'top_docs': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': [{'key': 'building control act (chapter 29) 2197',
#      'doc_count': 17,
#      'action_date': {'count': 17,
#       'min': 599961600000.0,
#       'max': 599961600000.0,
#       'avg': 599961600000.0,
#       'sum': 10199347200000.0,
#       'min_as_string': '05/01/1989',
#       'max_as_string': '05/01/1989',
#       'avg_as_string': '05/01/1989',
#       'sum_as_string': '16/03/2293'},
#      'top_hit': {'value': 96.52226257324219},
#      'top_passage_hits': {'hits': {'total': {'value': 17, 'relation': 'eq'},
#        'max_score': 96.52226,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'N_c8-X8Bc5I5BGQX3PNP',
#          '_score': 96.52226,
#          '_source': {'document_name': 'Full text',
#           'for_search_action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_country_code': 'SGP',
#           'action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_source_name': 'CCLW',
#           'action_id': 1756,
#           'action_name': 'Building Control Act (Chapter 29)',
#           'action_date': '05/01/1989',
#           'action_name_and_id': 'Building Control Act (Chapter 29) 2197',
#           'document_id': 2197,
#           'action_geography_english_shortname': 'Singapore',
#           'action_type_name': 'Law'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'pfc8-X8Bc5I5BGQX3PNQ',
#          '_score': 82.639725,
#          '_source': {'action_country_code': 'SGP',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p2_b110',
#           'action_date': '05/01/1989',
#           'document_id': 2197,
#           'action_geography_english_shortname': 'Singapore',
#           'document_name': 'Full text',
#           'action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_id': 1756,
#           'action_name': 'Building Control Act (Chapter 29)',
#           'action_name_and_id': 'Building Control Act (Chapter 29) 2197',
#           'text': 'ENVIRONMENTAL SUSTAINABILITY MEASURES FOR EXISTING \nBUILDINGS',
#           'action_type_name': 'Law'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'VPc8-X8Bc5I5BGQX8f5q',
#          '_score': 82.63972,
#          '_source': {'action_country_code': 'SGP',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p71_b2845',
#           'action_date': '05/01/1989',
#           'document_id': 2197,
#           'action_geography_english_shortname': 'Singapore',
#           'document_name': 'Full text',
#           'action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_id': 1756,
#           'action_name': 'Building Control Act (Chapter 29)',
#           'action_name_and_id': 'Building Control Act (Chapter 29) 2197',
#           'text': 'ENVIRONMENTAL SUSTAINABILITY MEASURES FOR \nEXISTING BUILDINGS',
#           'action_type_name': 'Law'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'gfc8-X8Bc5I5BGQX8f5q',
#          '_score': 82.563614,
#          '_source': {'action_country_code': 'SGP',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p72_b2890',
#           'action_date': '05/01/1989',
#           'document_id': 2197,
#           'action_geography_english_shortname': 'Singapore',
#           'document_name': 'Full text',
#           'action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_id': 1756,
#           'action_name': 'Building Control Act (Chapter 29)',
#           'action_name_and_id': 'Building Control Act (Chapter 29) 2197',
#           'text': 'minimum environmental sustainability standard',
#           'action_type_name': 'Law'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'EPg9-X8Bc5I5BGQXAggF',
#          '_score': 79.61493,
#          '_source': {'action_country_code': 'SGP',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p143_b5337',
#           'action_date': '05/01/1989',
#           'document_id': 2197,
#           'action_geography_english_shortname': 'Singapore',
#           'document_name': 'Full text',
#           'action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_id': 1756,
#           'action_name': 'Building Control Act (Chapter 29)',
#           'action_name_and_id': 'Building Control Act (Chapter 29) 2197',
#           'text': 'environmental sustainability measures that improve \nthe total quality of life and minimises adverse effects \nto the environment, both now and in the future;',
#           'action_type_name': 'Law'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'bvc8-X8Bc5I5BGQX8f5q',
#          '_score': 78.70952,
#          '_source': {'action_country_code': 'SGP',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p72_b2871',
#           'action_date': '05/01/1989',
#           'document_id': 2197,
#           'action_geography_english_shortname': 'Singapore',
#           'document_name': 'Full text',
#           'action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_id': 1756,
#           'action_name': 'Building Control Act (Chapter 29)',
#           'action_name_and_id': 'Building Control Act (Chapter 29) 2197',
#           'text': 'means a numerical score to assess the \nenvironmental sustainability of a building, calculated using \nthe prescribed scoring methodology;',
#           'action_type_name': 'Law'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'FPg9-X8Bc5I5BGQXAggF',
#          '_score': 77.789665,
#          '_source': {'action_country_code': 'SGP',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p143_b5341',
#           'action_date': '05/01/1989',
#           'document_id': 2197,
#           'action_geography_english_shortname': 'Singapore',
#           'document_name': 'Full text',
#           'action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_id': 1756,
#           'action_name': 'Building Control Act (Chapter 29)',
#           'action_name_and_id': 'Building Control Act (Chapter 29) 2197',
#           'text': ') the minimum standards of environmental sustainability for \nbuildings or classes or types of buildings, and the method \nby which such standards may be assessed;',
#           'action_type_name': 'Law'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'GPg9-X8Bc5I5BGQXAggG',
#          '_score': 76.94856,
#          '_source': {'action_country_code': 'SGP',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p143_b5345',
#           'action_date': '05/01/1989',
#           'document_id': 2197,
#           'action_geography_english_shortname': 'Singapore',
#           'document_name': 'Full text',
#           'action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_id': 1756,
#           'action_name': 'Building Control Act (Chapter 29)',
#           'action_name_and_id': 'Building Control Act (Chapter 29) 2197',
#           'text': ') the manner in which an assessment of environmental \nsustainability of a building or an audit of the energy \nefficiency of a cooling system of a building is to be carried \nout;',
#           'action_type_name': 'Law'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'g_c8-X8Bc5I5BGQX8f5r',
#          '_score': 76.12767,
#          '_source': {'action_country_code': 'SGP',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p72_b2892',
#           'action_date': '05/01/1989',
#           'document_id': 2197,
#           'action_geography_english_shortname': 'Singapore',
#           'document_name': 'Full text',
#           'action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_id': 1756,
#           'action_name': 'Building Control Act (Chapter 29)',
#           'action_name_and_id': 'Building Control Act (Chapter 29) 2197',
#           'text': ', in relation to \nany building, means the prescribed minimum standard of \nenvironmental sustainability applicable to that building, or to \na building of that type or class, expressed in terms of a Green \nMark score and other specified requirements;',
#           'action_type_name': 'Law'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '4vc8-X8Bc5I5BGQX8f5r',
#          '_score': 75.27895,
#          '_source': {'action_country_code': 'SGP',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p75_b2987',
#           'action_date': '05/01/1989',
#           'document_id': 2197,
#           'action_geography_english_shortname': 'Singapore',
#           'document_name': 'Full text',
#           'action_description': 'This Act prescribes standards of safety, accessibility, environmental sustainability and buildability. The legislation provides a blueprint to regulate the design of building works and the periodic structural inspection of existing structures.\xa0\xa0On 15 April 2008, the Act was enhanced to incorporate the Building Control (Environmental Sustainability) Regulations. This regulation requires developers and owners of new building projects as well as existing building projects involving major retrofitting (with Gross Floor Areas of 2000m2 or more) to meet the compliance standard which was modelled after the basic Green Mark certified standard. Under this requirement, the professionals appointed by the developers or owners would have to ensure that the building design meet at least 28% energy efficiency improvement from 2005 codes along with other salient aspects of environmental sustainability such as water efficiency, indoor environmental quality, environmental management and the use of green building technologies.\xa0\xa0On 01 December 2012,the Building Control (Environmental Sustainability Measures for Existing Buildings) Regulations was introduced to the Building Control Act (Act), requiring building owners to:\xa0- Comply with the minimum environmental sustainability standard (Green Mark Standard) for existing buildings, as and when they retrofit their cooling system (effective from 2 Jan 2014);\xa0- Submit periodic energy efficiency audits of building cooling systems; and\xa0- Submit information in respect of energy consumption and other related information as required by the Commissioner of Building Control (effective from 1 July 2013).',
#           'action_id': 1756,
#           'action_name': 'Building Control Act (Chapter 29)',
#           'action_name_and_id': 'Building Control Act (Chapter 29) 2197',
#           'text': 'shall ensure that the design score for the major energy-use \nchange with such departure or deviation still meets the \nminimum environmental sustainability standard, subject to \nany modification or waiver under section 22FB(5); but',
#           'action_type_name': 'Law'}}]}}},
#     {'key': 'national renewable energy policy (nrep) 2842',
#      'doc_count': 10,
#      'action_date': {'count': 10,
#       'min': 1584576000000.0,
#       'max': 1584576000000.0,
#       'avg': 1584576000000.0,
#       'sum': 15845760000000.0,
#       'min_as_string': '19/03/2020',
#       'max_as_string': '19/03/2020',
#       'avg_as_string': '19/03/2020',
#       'sum_as_string': '18/02/2472'},
#      'top_hit': {'value': 87.58554077148438},
#      'top_passage_hits': {'hits': {'total': {'value': 10, 'relation': 'eq'},
#        'max_score': 87.58554,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'lPg--X8Bc5I5BGQXDX_h',
#          '_score': 87.58554,
#          '_source': {'action_country_code': 'ZWE',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p19_b108',
#           'action_date': '19/03/2020',
#           'document_id': 2842,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Zimbabwe',
#           'document_name': '2019 draft policy',
#           'action_description': "The National Renewable Energy Policy is the government's key document aimed at fostering the production and use of renewable sources in the grid and off-grid. It aims to raise the share of renewables in the energy mix by creating incentives from supply, to distribution and demand, in urban and rural settings.It is not clear whether the incentives and targets set out in the 2019 draft are to be implemented through the current version which is unavailable.",
#           'action_id': 2266,
#           'action_name': 'National Renewable Energy Policy (NREP)',
#           'action_name_and_id': 'National Renewable Energy Policy (NREP) 2842',
#           'text': 'Sustainability –',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'l_g--X8Bc5I5BGQXEIKY',
#          '_score': 87.43281,
#          '_source': {'action_country_code': 'ZWE',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p48_b879',
#           'action_date': '19/03/2020',
#           'document_id': 2842,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Zimbabwe',
#           'document_name': '2019 draft policy',
#           'action_description': "The National Renewable Energy Policy is the government's key document aimed at fostering the production and use of renewable sources in the grid and off-grid. It aims to raise the share of renewables in the energy mix by creating incentives from supply, to distribution and demand, in urban and rural settings.It is not clear whether the incentives and targets set out in the 2019 draft are to be implemented through the current version which is unavailable.",
#           'action_id': 2266,
#           'action_name': 'National Renewable Energy Policy (NREP)',
#           'action_name_and_id': 'National Renewable Energy Policy (NREP) 2842',
#           'text': 'Sustainability:',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'Pvg--X8Bc5I5BGQXEIKX',
#          '_score': 77.61095,
#          '_source': {'action_country_code': 'ZWE',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p45_b790',
#           'action_date': '19/03/2020',
#           'document_id': 2842,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Zimbabwe',
#           'document_name': '2019 draft policy',
#           'action_description': "The National Renewable Energy Policy is the government's key document aimed at fostering the production and use of renewable sources in the grid and off-grid. It aims to raise the share of renewables in the energy mix by creating incentives from supply, to distribution and demand, in urban and rural settings.It is not clear whether the incentives and targets set out in the 2019 draft are to be implemented through the current version which is unavailable.",
#           'action_id': 2266,
#           'action_name': 'National Renewable Energy Policy (NREP)',
#           'action_name_and_id': 'National Renewable Energy Policy (NREP) 2842',
#           'text': 'Ensure that bio-fuel production, processing, distribution and marketing remain within the parameters of \neconomic, environmental and social sustainability.',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'pPg--X8Bc5I5BGQXEIKY',
#          '_score': 71.10855,
#          '_source': {'action_country_code': 'ZWE',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p49_b892',
#           'action_date': '19/03/2020',
#           'document_id': 2842,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Zimbabwe',
#           'document_name': '2019 draft policy',
#           'action_description': "The National Renewable Energy Policy is the government's key document aimed at fostering the production and use of renewable sources in the grid and off-grid. It aims to raise the share of renewables in the energy mix by creating incentives from supply, to distribution and demand, in urban and rural settings.It is not clear whether the incentives and targets set out in the 2019 draft are to be implemented through the current version which is unavailable.",
#           'action_id': 2266,
#           'action_name': 'National Renewable Energy Policy (NREP)',
#           'action_name_and_id': 'National Renewable Energy Policy (NREP) 2842',
#           'text': 'Food Security:',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'jfg--X8Bc5I5BGQXDX_h',
#          '_score': 71.037544,
#          '_source': {'action_country_code': 'ZWE',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p19_b101',
#           'action_date': '19/03/2020',
#           'document_id': 2842,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Zimbabwe',
#           'document_name': '2019 draft policy',
#           'action_description': "The National Renewable Energy Policy is the government's key document aimed at fostering the production and use of renewable sources in the grid and off-grid. It aims to raise the share of renewables in the energy mix by creating incentives from supply, to distribution and demand, in urban and rural settings.It is not clear whether the incentives and targets set out in the 2019 draft are to be implemented through the current version which is unavailable.",
#           'action_id': 2266,
#           'action_name': 'National Renewable Energy Policy (NREP)',
#           'action_name_and_id': 'National Renewable Energy Policy (NREP) 2842',
#           'text': 'To provide energy access to all in a sustainable manner by increasing the mix of RE sources.',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '-_g--X8Bc5I5BGQXDX_i',
#          '_score': 5.4656653,
#          '_source': {'action_country_code': 'ZWE',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p24_b211',
#           'action_date': '19/03/2020',
#           'document_id': 2842,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Zimbabwe',
#           'document_name': '2019 draft policy',
#           'action_description': "The National Renewable Energy Policy is the government's key document aimed at fostering the production and use of renewable sources in the grid and off-grid. It aims to raise the share of renewables in the energy mix by creating incentives from supply, to distribution and demand, in urban and rural settings.It is not clear whether the incentives and targets set out in the 2019 draft are to be implemented through the current version which is unavailable.",
#           'action_id': 2266,
#           'action_name': 'National Renewable Energy Policy (NREP)',
#           'action_name_and_id': 'National Renewable Energy Policy (NREP) 2842',
#           'text': 'To design the schemes based on the policy principles of affordability, accessibility, sustainability, \ndevelopment and gender equity.',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '8_g--X8Bc5I5BGQXEIGX',
#          '_score': 3.8963814,
#          '_source': {'action_country_code': 'ZWE',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p42_b715',
#           'action_date': '19/03/2020',
#           'document_id': 2842,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Zimbabwe',
#           'document_name': '2019 draft policy',
#           'action_description': "The National Renewable Energy Policy is the government's key document aimed at fostering the production and use of renewable sources in the grid and off-grid. It aims to raise the share of renewables in the energy mix by creating incentives from supply, to distribution and demand, in urban and rural settings.It is not clear whether the incentives and targets set out in the 2019 draft are to be implemented through the current version which is unavailable.",
#           'action_id': 2266,
#           'action_name': 'National Renewable Energy Policy (NREP)',
#           'action_name_and_id': 'National Renewable Energy Policy (NREP) 2842',
#           'text': 'It is essential to initiate \nResearch and Development activities related to RE technologies which is pivotal for long-term sustainability \nof the industry and developing tailor made solutions for the Zimbabwean market.',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'n_g--X8Bc5I5BGQXEIGW',
#          '_score': 3.7527199,
#          '_source': {'action_country_code': 'ZWE',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p40_b631',
#           'action_date': '19/03/2020',
#           'document_id': 2842,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Zimbabwe',
#           'document_name': '2019 draft policy',
#           'action_description': "The National Renewable Energy Policy is the government's key document aimed at fostering the production and use of renewable sources in the grid and off-grid. It aims to raise the share of renewables in the energy mix by creating incentives from supply, to distribution and demand, in urban and rural settings.It is not clear whether the incentives and targets set out in the 2019 draft are to be implemented through the current version which is unavailable.",
#           'action_id': 2266,
#           'action_name': 'National Renewable Energy Policy (NREP)',
#           'action_name_and_id': 'National Renewable Energy Policy (NREP) 2842',
#           'text': 'For promotion of these programmes, planning shall be carried out to study willingness of people to pay, \naffordability, sustainability and efficiency. Committees shall be formed at the village level keeping in mind \ngender diversity.',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'T_g--X8Bc5I5BGQXDYDi',
#          '_score': 2.8979301,
#          '_source': {'action_country_code': 'ZWE',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p27_b295',
#           'action_date': '19/03/2020',
#           'document_id': 2842,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Zimbabwe',
#           'document_name': '2019 draft policy',
#           'action_description': "The National Renewable Energy Policy is the government's key document aimed at fostering the production and use of renewable sources in the grid and off-grid. It aims to raise the share of renewables in the energy mix by creating incentives from supply, to distribution and demand, in urban and rural settings.It is not clear whether the incentives and targets set out in the 2019 draft are to be implemented through the current version which is unavailable.",
#           'action_id': 2266,
#           'action_name': 'National Renewable Energy Policy (NREP)',
#           'action_name_and_id': 'National Renewable Energy Policy (NREP) 2842',
#           'text': 'Geothermal energy is comparatively new technology and therefore further resource \nassessments needs to be carried out. Keeping this in consideration, FiT shall be the suitable procurement \nmechanism to spur growth in the development of this technology. Pilot projects shall be implemented for \ngeothermal energy to prove its sustainability and scalability.',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'Wvg--X8Bc5I5BGQXDX_g',
#          '_score': 1.8805819,
#          '_source': {'action_country_code': 'ZWE',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p8_b50',
#           'action_date': '19/03/2020',
#           'document_id': 2842,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Zimbabwe',
#           'document_name': '2019 draft policy',
#           'action_description': "The National Renewable Energy Policy is the government's key document aimed at fostering the production and use of renewable sources in the grid and off-grid. It aims to raise the share of renewables in the energy mix by creating incentives from supply, to distribution and demand, in urban and rural settings.It is not clear whether the incentives and targets set out in the 2019 draft are to be implemented through the current version which is unavailable.",
#           'action_id': 2266,
#           'action_name': 'National Renewable Energy Policy (NREP)',
#           'action_name_and_id': 'National Renewable Energy Policy (NREP) 2842',
#           'text': 'The policy also includes provisions for promoting manufacturing of renewable energy equipment. Specific incentives \nsuch as domestic content requirement for renewable energy systems installed in the country, approved standards \nand specifications, and financial and tax incentives aim to promote domestic manufacturing of renewable energy \nequipment. The policy also provides recommendations to design and initiate skill development programs to build \ncapacity of the population and enable access to a skilled labour base. It has also made provisions to initiate Research \nand Development activities in renewable energy technologies for the long-term sustainability of the sector.',
#           'action_type_name': 'Policy'}}]}}},
#     {'key': 'perspective development strategic programme for 2014-2025 99',
#      'doc_count': 8,
#      'action_date': {'count': 8,
#       'min': 1419465600000.0,
#       'max': 1419465600000.0,
#       'avg': 1419465600000.0,
#       'sum': 11355724800000.0,
#       'min_as_string': '25/12/2014',
#       'max_as_string': '25/12/2014',
#       'avg_as_string': '25/12/2014',
#       'sum_as_string': '07/11/2329'},
#      'top_hit': {'value': 85.36650848388672},
#      'top_passage_hits': {'hits': {'total': {'value': 8, 'relation': 'eq'},
#        'max_score': 85.36651,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'nPg9-X8Bc5I5BGQXgj6W',
#          '_score': 85.36651,
#          '_source': {'action_country_code': 'ARM',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p48_b1324',
#           'action_date': '25/12/2014',
#           'document_id': 99,
#           'action_geography_english_shortname': 'Armenia',
#           'document_name': 'Full text',
#           'action_description': "This document sets Armenia's development strategy for the period 2014-2025. It notably seeks to maximise the use of renewable energy sources, promote energy efficiency in all sectors, protect the atmosphere by reducing GHG emissions including from the transport sector, and foster reforestation efforts.",
#           'action_id': 83,
#           'action_name': 'Perspective Development Strategic Programme for 2014-2025',
#           'action_name_and_id': 'Perspective Development Strategic Programme for 2014-2025 99',
#           'text': 'sustainability of first',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'w_g9-X8Bc5I5BGQXj0NO',
#          '_score': 81.446236,
#          '_source': {'action_country_code': 'ARM',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p97_b2643',
#           'action_date': '25/12/2014',
#           'document_id': 99,
#           'action_geography_english_shortname': 'Armenia',
#           'document_name': 'Full text',
#           'action_description': "This document sets Armenia's development strategy for the period 2014-2025. It notably seeks to maximise the use of renewable energy sources, promote energy efficiency in all sectors, protect the atmosphere by reducing GHG emissions including from the transport sector, and foster reforestation efforts.",
#           'action_id': 83,
#           'action_name': 'Perspective Development Strategic Programme for 2014-2025',
#           'action_name_and_id': 'Perspective Development Strategic Programme for 2014-2025 99',
#           'text': 'term sustainability of the pension system.',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '3fg9-X8Bc5I5BGQXhj73',
#          '_score': 80.88829,
#          '_source': {'action_country_code': 'ARM',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p50_b1389',
#           'action_date': '25/12/2014',
#           'document_id': 99,
#           'action_geography_english_shortname': 'Armenia',
#           'document_name': 'Full text',
#           'action_description': "This document sets Armenia's development strategy for the period 2014-2025. It notably seeks to maximise the use of renewable energy sources, promote energy efficiency in all sectors, protect the atmosphere by reducing GHG emissions including from the transport sector, and foster reforestation efforts.",
#           'action_id': 83,
#           'action_name': 'Perspective Development Strategic Programme for 2014-2025',
#           'action_name_and_id': 'Perspective Development Strategic Programme for 2014-2025 99',
#           'text': 'sustainability for \nbasic foodstuffs, reduction of rural poverty and migration.',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'qPg9-X8Bc5I5BGQXlkba',
#          '_score': 74.535675,
#          '_source': {'action_country_code': 'ARM',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p128_b3384',
#           'action_date': '25/12/2014',
#           'document_id': 99,
#           'action_geography_english_shortname': 'Armenia',
#           'document_name': 'Full text',
#           'action_description': "This document sets Armenia's development strategy for the period 2014-2025. It notably seeks to maximise the use of renewable energy sources, promote energy efficiency in all sectors, protect the atmosphere by reducing GHG emissions including from the transport sector, and foster reforestation efforts.",
#           'action_id': 83,
#           'action_name': 'Perspective Development Strategic Programme for 2014-2025',
#           'action_name_and_id': 'Perspective Development Strategic Programme for 2014-2025 99',
#           'text': 'The cornerstone of the environmental component of sustainable development is the \nprotection of the balanced environment through conducting a resource efficient economy.',
#           'action_type_name': 'Policy'}},
#         {'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'rvg9-X8Bc5I5BGQXnEgd',
#          '_score': 6.313224,
#          '_source': {'action_country_code': 'ARM',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p141_b3902',
#           'action_date': '25/12/2014',
#           'document_id': 99,
#           'action_geography_english_shortname': 'Armenia',
#           'document_name': 'Full text',
#           'action_description': "This document sets Armenia's development strategy for the period 2014-2025. It notably seeks to maximise the use of renewable energy sources, promote energy efficiency in all sectors, protect the atmosphere by reducing GHG emissions including from the transport sector, and foster reforestation efforts.",
#           'action_id': 83,
#           'action_name': 'Perspective Development Strategic Programme for 2014-2025',
# ...
#           'action_source_name': 'CCLW',
#           'action_id': 65,
#           'action_name': 'National Physical Development Plan',
#           'action_date': '25/12/2012',
#           'action_name_and_id': 'National Physical Development Plan 74',
#           'document_id': 74,
#           'action_geography_english_shortname': 'Antigua and Barbuda',
#           'action_type_name': 'Policy'}}]}}},
#     {'key': 'climate change action plan 2011-2023 2545',
#      'doc_count': 1,
#      'action_date': {'count': 1,
#       'min': 1296864000000.0,
#       'max': 1296864000000.0,
#       'avg': 1296864000000.0,
#       'sum': 1296864000000.0,
#       'min_as_string': '05/02/2011',
#       'max_as_string': '05/02/2011',
#       'avg_as_string': '05/02/2011',
#       'sum_as_string': '05/02/2011'},
#      'top_hit': {'value': 7.5608367919921875},
#      'top_passage_hits': {'hits': {'total': {'value': 1, 'relation': 'eq'},
#        'max_score': 7.560837,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'jPg9-X8Bc5I5BGQXCA0g',
#          '_score': 7.560837,
#          '_source': {'action_country_code': 'TUR',
#           'action_source_name': 'CCLW',
#           'action_date': '05/02/2011',
#           'document_id': 2545,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'Turkey',
#           'document_name': 'English version',
#           'for_search_action_description': "The Action Plan sets out a road map with short, medium and long-term plans for the fight against climate change encompassing all sectors of the economy.\xa0\xa0Overall the plan involves providing climate-friendly goals that underpin Turkey's growth. These include: strengthening the existing information structure on low carbon progress, and developing financing models for the transition to a low carbon economy. This is with the aim of improving the fiscal and technical infrastructure to enable the limitation of GHG emissions Some details of the extensive Plan are highlighted below:\xa0\xa0Energy\xa0The plan includes a number of measurable goals regarding energy supply, efficiency standards in residential and commercial buildings, and incentivising renewables. For example:\xa0- Reducing primary energy intensity by 10% compared to 2008 by 2015\xa0Limiting GHG emissions from coal-fired electricity production, by using cleaner technologies and taking efficiency-increasing measures by increasing the average cycle efficiencies of existing coal-fired thermal power plants until 2023\xa0- Issuing 'Energy Performance Certificates' to all buildings until 2017\xa0- Decreasing annual energy consumption in the buildings and premises of public institutions by 10% until 2015 and by 20% until 2023\xa0- At least 20% of the annual energy demand of new buildings will be met via renewable energy resources as of 2017\xa0- Reducing GHG emissions in new settlements by at least 10% in comparison with existing settlements (which are selected as pilot regions and the GHG emissions of which are identified until 2015) until 2023.\xa0\xa0Forestry\xa0- Increase forest carbon sequestration by 15% of 2007 value until 2020 ( 14,500 Gg by 2007, 16,700 Gg by 2020)\xa0- Reduce deforestation and forest damage by 20% compared to 2007 values by 2020\xa0\xa0Land use change\xa0- Integrate climate change in land use and land use changes management strategies by 2015\xa0- Increase the amount of sequestered carbon in agricultural forestry activities by 10% by 2020 compared to 2007 values\xa0- Quantify the carbon stored in pastures and meadows in 2012. Increase this by 3% by 2020\xa0\xa0Transportation\xa0The plan aims to ensure the balanced use of types of passenger and freight transportation, specifically:\xa0- Increasing the share of railroads in freight transportation from 5% in 2009 to 15%, and in passenger transportation from 2% in 2009 to 10% by 2023\xa0- Increasing by 2023, the share of seaways in freight transportation from 2.66% of tonne/km in 2009 to 10%, and in passenger transportation from 0.37% in passenger/km in 2009 to 4%,\xa0- Decreasing by 2023 the share of highways in freight transportation from 80.63% of tonne/km in 2009 to below 60%, and in passenger transportation from 89.59% in passenger/km in 2009 to 72%\xa0- Developing the necessary legislation, institutional structure and guidance documents until the end of 2023 for implementation of sustainable transportation planning in cities\xa0- Dissemination of the use of alternative fuels and clean vehicle technologies in the transportation sector by making legal arrangements and building capacity to increase use of alternative fuels and clean vehicles until 2023\xa0- Increasing efficiency in energy consumption of transportation sector by limiting energy consumption in transportation until 2023.\xa0\xa0Adaptation objectives:\xa0\xa0- Integrating adaptation to the impacts of climate change into water resource management policies\xa0\xa0- Strengthening water resources management capacity, interagency cooperation and coordination with regard to adaptation to climate change\xa0\xa0- Develop and expand R&D and scientific studies to ensure adaptation to the impacts of climate change in water resources management\xa0\xa0- Integrated management of water resources and water basins for adaptation to climate change\xa0\xa0- Planning renewable energy resources taking into cons ...
#           'action_description': "The Action Plan sets out a road map with short, medium and long-term plans for the fight against climate change encompassing all sectors of the economy.\xa0\xa0Overall the plan involves providing climate-friendly goals that underpin Turkey's growth. These include: strengthening the existing information structure on low carbon progress, and developing financing models for the transition to a low carbon economy. This is with the aim of improving the fiscal and technical infrastructure to enable the limitation of GHG emissions Some details of the extensive Plan are highlighted below:\xa0\xa0Energy\xa0The plan includes a number of measurable goals regarding energy supply, efficiency standards in residential and commercial buildings, and incentivising renewables. For example:\xa0- Reducing primary energy intensity by 10% compared to 2008 by 2015\xa0Limiting GHG emissions from coal-fired electricity production, by using cleaner technologies and taking efficiency-increasing measures by increasing the average cycle efficiencies of existing coal-fired thermal power plants until 2023\xa0- Issuing 'Energy Performance Certificates' to all buildings until 2017\xa0- Decreasing annual energy consumption in the buildings and premises of public institutions by 10% until 2015 and by 20% until 2023\xa0- At least 20% of the annual energy demand of new buildings will be met via renewable energy resources as of 2017\xa0- Reducing GHG emissions in new settlements by at least 10% in comparison with existing settlements (which are selected as pilot regions and the GHG emissions of which are identified until 2015) until 2023.\xa0\xa0Forestry\xa0- Increase forest carbon sequestration by 15% of 2007 value until 2020 ( 14,500 Gg by 2007, 16,700 Gg by 2020)\xa0- Reduce deforestation and forest damage by 20% compared to 2007 values by 2020\xa0\xa0Land use change\xa0- Integrate climate change in land use and land use changes management strategies by 2015\xa0- Increase the amount of sequestered carbon in agricultural forestry activities by 10% by 2020 compared to 2007 values\xa0- Quantify the carbon stored in pastures and meadows in 2012. Increase this by 3% by 2020\xa0\xa0Transportation\xa0The plan aims to ensure the balanced use of types of passenger and freight transportation, specifically:\xa0- Increasing the share of railroads in freight transportation from 5% in 2009 to 15%, and in passenger transportation from 2% in 2009 to 10% by 2023\xa0- Increasing by 2023, the share of seaways in freight transportation from 2.66% of tonne/km in 2009 to 10%, and in passenger transportation from 0.37% in passenger/km in 2009 to 4%,\xa0- Decreasing by 2023 the share of highways in freight transportation from 80.63% of tonne/km in 2009 to below 60%, and in passenger transportation from 89.59% in passenger/km in 2009 to 72%\xa0- Developing the necessary legislation, institutional structure and guidance documents until the end of 2023 for implementation of sustainable transportation planning in cities\xa0- Dissemination of the use of alternative fuels and clean vehicle technologies in the transportation sector by making legal arrangements and building capacity to increase use of alternative fuels and clean vehicles until 2023\xa0- Increasing efficiency in energy consumption of transportation sector by limiting energy consumption in transportation until 2023.\xa0\xa0Adaptation objectives:\xa0\xa0- Integrating adaptation to the impacts of climate change into water resource management policies\xa0\xa0- Strengthening water resources management capacity, interagency cooperation and coordination with regard to adaptation to climate change\xa0\xa0- Develop and expand R&D and scientific studies to ensure adaptation to the impacts of climate change in water resources management\xa0\xa0- Integrated management of water resources and water basins for adaptation to climate change\xa0\xa0- Planning renewable energy resources taking into consideration t ...
#           'action_id': 2028,
#           'action_name': 'Climate Change Action Plan 2011-2023',
#           'action_name_and_id': 'Climate Change Action Plan 2011-2023 2545',
#           'action_type_name': 'Policy'}}]}}},
#     {'key': 'gear change, a bold vision for cycling and walking (cycling and walking plan for england) 2659',
#      'doc_count': 1,
#      'action_date': {'count': 1,
#       'min': 1595894400000.0,
#       'max': 1595894400000.0,
#       'avg': 1595894400000.0,
#       'sum': 1595894400000.0,
#       'min_as_string': '28/07/2020',
#       'max_as_string': '28/07/2020',
#       'avg_as_string': '28/07/2020',
#       'sum_as_string': '28/07/2020'},
#      'top_hit': {'value': 4.219440460205078},
#      'top_passage_hits': {'hits': {'total': {'value': 1, 'relation': 'eq'},
#        'max_score': 4.2194405,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': '1_g--X8Bc5I5BGQXE4N7',
#          '_score': 4.2194405,
#          '_source': {'action_country_code': 'GBR',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p24_b202',
#           'action_date': '28/07/2020',
#           'document_id': 2659,
#           'document_language_id': 1826.0,
#           'action_geography_english_shortname': 'United Kingdom',
#           'document_name': 'Full text (PDF)',
#           'action_description': 'This document aims fostering walking and cycling in England. Four themes are laid out in the document: 1) better streets for cycling and people, 2) cycling and walking at the heart of decision-making, 3) empowering and encouraging local authorities, 4) enabling people to cycle and protecting them when they do. Physical and mental health is explicitly mentioned as an argument for increasing walking and cycling rates.Under this plan, the government will build more (protected) cycle lanes, provide cycle training for everyone and bikes available on prescription. It will also create a long term cycling programme, consult to strengthen the Highway Code for safety purposes, support local authorities to crack down on traffic offenses, create low traffic neighbourhoods to improve air quality, focus on areas with poor average health and increase access to e-bikes.\xa0A budget of two billion pounds has been allocated to this plan. Bike repair vouchers worth £50 will be released under a pilot plan. A scheme to support bike repairers is also considered.',
#           'action_id': 2113,
#           'action_name': 'Gear Change, A bold vision for cycling and walking (Cycling and walking plan for England)',
#           'action_name_and_id': 'Gear Change, A bold vision for cycling and walking (Cycling and walking plan for England) 2659',
#           'text': 'Significant improvements have been made to the assessment of benefits \nsuch as health and sustainability in transport schemes, including through \nthe Department for Transport’s Active Mode Appraisal Toolkit',
#           'action_type_name': 'Policy'}}]}}},
#     {'key': 'national climate adaptation strategy 1723',
#      'doc_count': 1,
#      'action_date': {'count': 1,
#       'min': 1452556800000.0,
#       'max': 1452556800000.0,
#       'avg': 1452556800000.0,
#       'sum': 1452556800000.0,
#       'min_as_string': '12/01/2016',
#       'max_as_string': '12/01/2016',
#       'avg_as_string': '12/01/2016',
#       'sum_as_string': '12/01/2016'},
#      'top_hit': {'value': 3.5560483932495117},
#      'top_passage_hits': {'hits': {'total': {'value': 1, 'relation': 'eq'},
#        'max_score': 3.5560484,
#        'hits': [{'_index': 'navigator',
#          '_type': '_doc',
#          '_id': 'qvg9-X8Bc5I5BGQX1mPn',
#          '_score': 3.5560484,
#          '_source': {'action_country_code': 'NLD',
#           'action_source_name': 'CCLW',
#           'text_block_id': 'p46_b423',
#           'action_date': '12/01/2016',
#           'document_id': 1723,
#           'action_geography_english_shortname': 'Netherlands',
#           'document_name': 'Full text',
#           'action_description': "This National Climate Adaptation Strategy introduces various new initiatives and will accelerate the progress of ongoing initiatives in the Netherlands.\xa0\xa0The NAS uses four diagrams ('Hotter', 'Wetter', 'Drier' and 'Rising Sea Level') to visualise the effects of climate change within nine sectors: water and spatial management; nature; agriculture, horticulture and fisheries; health and welfare; recreation and tourism; infrastructure (road, rail, water and aviation); energy; IT and telecommunications; public safety and security.\xa0\xa0Six climate effects which call for immediate action are identified: 1) Greater heat stress leading to increased morbidity, hospital admissions and mortality,\xa0as well as reduced productivity, 2) More frequent failure of vital systems: energy, telecommunications, IT and transport\xa0infrastructures, 3) More frequent crop failures or other problems in the agricultural sector, such as\xa0decreased yields or damage to production resources, 4) Shifting climate zones whereby some flora and fauna species will be unable to migrate or\xa0adapt, due in part to the lack of an internationally coordinated spatial policy, 5) Greater health burden and loss of productivity due to possible increase in infectious\xa0diseases or allergic (respiratory) conditions such as hay fever, and 6) Cumulative effects whereby a systems failure in one sector or at one location triggers\xa0further problems elsewhere.",
#           'action_id': 1371,
#           'action_name': 'National Climate Adaptation Strategy',
#           'action_name_and_id': 'National Climate Adaptation Strategy 1723',
#           'text': 'Rijkswaterstaat and the Ministry of Infrastructure and the Environment wish to approach \nthe roads infrastructure with due regard for urbanization, sustainability and climate \nadaptation but experience difficulties due to the current division of responsibilities and \nbudgetary issues.',
#           'action_type_name': 'Policy'}}]}}}]},
#   'bucketcount': {'count': 38,
#    'min': 1.0,
#    'max': 82.0,
#    'avg': 13.657894736842104,
#    'sum': 519.0}}}
